# %% [markdown]
# Named Entity Recognition and Dependency Parsing for Information Extration using spacy.
#
# 1. Consider any text file (research article, technical blog or any unstructured corpus used before) <br>
# 2. Perform NER to extract entities from individual sentences using spacy. <br>
# 3. Use Dependency Parsing, POS tagging to extract relationships between the entities.
# 4. Create a tuple for Information Extraction <br>
# T1( Entity1, Entity2, Relation label)
# 5. Display no of such tuples extracted from considered corpus as extracted information

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('Life is a gift from god.Do your Best.everything is a blessing.')

# %%
# Cannot identify because sentences isn't properly ended
for sent in doc.sents:
    print(sent)
# Out:
# Life is a gift from god.
# Do your Best.everything is a blessing.

# %%
for word in doc:
    print(word.text, word.tag_, word.pos_, word.dep_)
    
# Explain the tags
spacy.explain('pobj')
spacy.explain('nsubj')
# Out:
# Life NN NOUN nsubj
# is VBZ AUX ROOT
# a DT DET det
# gift NN NOUN attr
# from IN ADP prep
# god NNP PROPN pobj
# . . PUNCT punct
# Do VBP AUX csubj
# your PRP$ PRON dobj
# Best.everything NFP PUNCT nsubj
# is VBZ AUX ROOT
# a DT DET det
# blessing NN NOUN attr
# . . PUNCT punct
# 'nominal subject'

# %%
doc.text.split()
# Out:
# ['Life',
#  'is',
#  'a',
#  'gift',
#  'from',
#  'god.Do',
#  'your',
#  'Best.everything',
#  'is',
#  'a',
#  'blessing.']

# %% [markdown]
# ## Name Entity Recognition

# %%
kalam= "A. P. J. Abdul Kalam was an Indian aerospace scientist and politician who served as the 11th President of India from 2002 to 2007. He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering. He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts."

# %%
nlp_kalam = nlp(kalam)
[(i, i.label_, i.label) for i in nlp_kalam.ents]
# Out:
# [(A. P. J. Abdul Kalam, 'PERSON', 380),
#  (Indian, 'NORP', 381),
#  (11th, 'ORDINAL', 396),
#  (India, 'GPE', 384),
#  (2002, 'DATE', 391),
#  (2007, 'DATE', 391),
#  (Rameswaram, 'GPE', 384),
#  (Tamil Nadu, 'PERSON', 380),
#  (the next four decades, 'DATE', 391),
#  (the Defence Research and Development Organisation, 'ORG', 383),
#  (Indian Space Research Organisation, 'ORG', 383),
#  (India, 'GPE', 384)]

# %%
from spacy import displacy
displacy.render(nlp_kalam, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A. P. J. Abdul Kalam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  aerospace scientist and politician who served as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  President of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . He was born and raised in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rameswaram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamil Nadu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and studied physics and aerospace engineering. He spent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the next four decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as a scientist and science administrator, mainly at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Defence Research and Development Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (DRDO) and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian Space Research Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ISRO) and was intimately involved in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's civilian space programme and military missile development efforts.</div></span>

# %% [markdown]
# ### 1. Consider any text file (research article, technical blog or any unstructured corpus used before) <br>
# ### 2. Perform NER to extract entities from individual sentences using spacy. <br>

# %% [markdown]
# #### Corpus - ABC

# %%
# printing 3000 words
import nltk
data = nltk.corpus.abc.raw('science.txt')[:3000]
print(data)
# Out:
# Cystic fibrosis affects 30,000 children and young adults in the US alone
# Inhaling the mists of salt water can reduce the pus and infection that fills the airways of cystic fibrosis sufferers, although side effects include a nasty coughing fit and a harsh taste.
# That's the conclusion of two studies published in this week's issue of The New England Journal of Medicine.
# They found that inhaling a mist with a salt content of 7 or 9% improved lung function and, in some cases, produced less absenteeism from school or work.
# Cystic fibrosis, a progressive and frequently fatal genetic disease that affects about 30,000 young adults and children in the US alone, is marked by a thickening of the mucus which makes it harder to clear the lungs of debris and bacteria.
# The salt water solution "really opens up a new avenue for approaching patients with cystic fibrosis and how to treat them," says Dr Gail Weinmann, of the US National Heart, Lung, and Blood Institute, which sponsored one of the studies.
# Mark Elkins of the Royal Prince Alfred Hospital in Sydney, Australia and colleagues authored one of the new published studies.
# The team found that the 83 volunteers who regularly inhaled a 7% mist of salty water had fewer breathing problems and less absenteeism from school or work than those who inhaled a solution with a salt content of under 1%.
# "Adding salt [and water] to the airway surfaces of patients with cystic fibrosis is beneficial" for both children and adults, they conclude.
# All of the patients first inhaled a chemical to try to open their lung passages as much as possible.
# In the second study, US-based Assistant Profsesor Scott Donaldson of the University of North Carolina at Chapel Hill and his colleagues found that a 7% salt mist "produced a sustained acceleration of mucus clearance and improved lung function" because it helped hydrate the lungs.
# In an accompanying editorial, Dr Felix Ratjen of the Hospital for Sick Children in Toronto, Canada, cited several unpleasant side effects of the salt mist treatment including a bad taste, coughing fits and the lengthy 30 minutes it can take to administer.
# He added that in the study by Elkins and team, patients may not have received the best long-term antibiotic treatment.
# That would make the inhaled salt water mist appear more effective than it would have been if people were getting a better drug, says Ratjen.
# Weinmann says limitations inherent to the treatment mean a salt water mist "may be just a first step" in treating cystic fibrosis.
#
# Scientists have rescued a mouse immune system that was overwhelmed by a systemic blood infection. But will this work in humans?
# Scientists have discovered how infections that invade the whole body, like malaria, disable the immune system and prevent it from detecting and fighting other microorganisms.
# The Australian and German researchers say the discovery may help scientists to develop vaccines that restore immunity in people with systemic or 'whol

# %%
nlp_data = nlp(data)
[(i, i.label_, i.label) for i in nlp_data.ents]
# Out:
# [(Cystic, 'NORP', 381),
#  (30,000, 'CARDINAL', 397),
#  (US, 'GPE', 384),
#  (two, 'CARDINAL', 397),
#  (week, 'DATE', 391),
#  (The New England Journal of Medicine, 'ORG', 383),
#  (7 or 9%, 'PERCENT', 393),
#  (Cystic, 'NORP', 381),
#  (about 30,000, 'CARDINAL', 397),
#  (US, 'GPE', 384),
#  (Gail Weinmann, 'PERSON', 380),
#  (the US National Heart, 'ORG', 383),
#  (Lung, 'PERSON', 380),
#  (Blood Institute, 'ORG', 383),
#  (one, 'CARDINAL', 397),
#  (Mark Elkins, 'PERSON', 380),
#  (the Royal Prince Alfred Hospital, 'ORG', 383),
#  (Sydney, 'GPE', 384),
#  (Australia, 'GPE', 384),
#  (83, 'CARDINAL', 397),
#  (7%, 'PERCENT', 393),
#  (under 1%, 'PERCENT', 393),
#  (first, 'ORDINAL', 396),
#  (second, 'ORDINAL', 396),
#  (US, 'GPE', 384),
#  (Profsesor Scott Donaldson, 'PERSON', 380),
#  (the University of North Carolina, 'ORG', 383),
#  (Chapel Hill, 'FAC', 9191306739292312949),
#  (7%, 'PERCENT', 393),
#  (Dr Felix Ratjen, 'ORG', 383),
#  (the Hospital for Sick Children, 'ORG', 383),
#  (Toronto, 'GPE', 384),
#  (Canada, 'GPE', 384),
#  (30 minutes, 'TIME', 392),
#  (Elkins, 'PERSON', 380),
#  (Weinmann, 'PERSON', 380),
#  (first, 'ORDINAL', 396),
#  (Australian, 'NORP', 381),
#  (German, 'NORP', 381)]

# %%
from spacy import displacy
displacy.render(nlp_data, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cystic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  fibrosis affects
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  children and young adults in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  alone
# </br>Inhaling the mists of salt water can reduce the pus and infection that fills the airways of cystic fibrosis sufferers, although side effects include a nasty coughing fit and a harsh taste.
# </br>That's the conclusion of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  studies published in this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's issue of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New England Journal of Medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# </br>They found that inhaling a mist with a salt content of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 or 9%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  improved lung function and, in some cases, produced less absenteeism from school or work.
# </br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cystic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  fibrosis, a progressive and frequently fatal genetic disease that affects
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 30,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  young adults and children in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  alone, is marked by a thickening of the mucus which makes it harder to clear the lungs of debris and bacteria.
# </br>The salt water solution &quot;really opens up a new avenue for approaching patients with cystic fibrosis and how to treat them,&quot; says Dr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gail Weinmann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US National Heart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blood Institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which sponsored
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the studies.
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Elkins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Royal Prince Alfred Hospital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sydney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and colleagues authored one of the new published studies.
# </br>The team found that the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     83
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  volunteers who regularly inhaled a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  mist of salty water had fewer breathing problems and less absenteeism from school or work than those who inhaled a solution with a salt content of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     under 1%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </m

# %% [markdown]
# ## Dependency Parsing

# %% [markdown]
#  Applying Dependency Parsing on single sentence.

# %%
from spacy import displacy
doc = nlp('India is my country. It is beautiful')
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5f0f195e1eee43f885a55e4c0695b6fb-0" class="displacy" width="680" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">country.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">beautiful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-0" stroke-width="2px" d="M70,92.0 C70,47.0 135.0,47.0 135.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,94.0 L62,82.0 78,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-1" stroke-width="2px" d="M250,92.0 C250,47.0 315.0,47.0 315.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,94.0 L242,82.0 258,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-2" stroke-width="2px" d="M160,92.0 C160,2.0 320.0,2.0 320.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,94.0 L328.0,82.0 312.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-3" stroke-width="2px" d="M430,92.0 C430,47.0 495.0,47.0 495.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,94.0 L422,82.0 438,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-4" stroke-width="2px" d="M520,92.0 C520,47.0 585.0,47.0 585.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f0f195e1eee43f885a55e4c0695b6fb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,94.0 L593.0,82.0 577.0,82.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Apply Dependency Parsing on the data (sentence by sentence)

# %%
from spacy import displacy
from nltk.tokenize import sent_tokenize
token_text_eng = sent_tokenize(data, language = 'english')
for i in token_text_eng:
    doc = nlp(i)
    displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1e3a8ea2e6624b7b9a17de310c88dc31-0" class="displacy" width="4100" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Cystic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">fibrosis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">affects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">30,000</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">young</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">adults</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">alone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">Inhaling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">mists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">salt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">water</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">reduce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">pus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">infection</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">fills</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">airways</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">cystic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADJ<
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e34c3f941c334b32b7429cecd78fc9e9-0" class="displacy" width="1850" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">That</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">conclusion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">studies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">week</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">issue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">England</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">Journal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">Medicine.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34c3f941c334b32b7429cecd78fc9e9-0-0" stroke-width="2px" d="M70,137.0 C70,92.0 130.0,92.0 130.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34c3f941c334b32b7429cecd78fc9e9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,139.0 L62,127.0 78,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34c3f941c334b32b7429cecd78fc9e9-0-1" stroke-width="2px" d="M250,137.0 C250,92.0 310.0,92.0 310.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34c3f941c334b32b7429cecd78fc9e9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,139.0 L242,127.0 258,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34c3f941c334b32b7429cecd78fc9e9-0-2" stroke-width="2px" d="M160,137.0 C160,47.0 315.0,47.0 315.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34c3f941c334b32b7429cecd78fc9e9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M315.0,139.0 L323.0,127.0 307.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34c3f941c334b32b7429cecd78fc9e9-0-3" stroke-width="2px" d="M340,137.0 C340,92.0 400.0,92.0 400.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34c3f941c334b32b7429cecd78fc9e9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,139.0 L408.0,127.0 392.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34c3f941c334b32b7429cecd78fc9e9-0-4" stroke-width="2px" d="M520,137.0 C520,92.0 580.0,92.0 580.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34c3f941c334b32b7429cecd78fc9e9-0-4" class="displacy-label" startOffset="50%" side="left"
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2ffafd3181c34077bf6e22144575be80-0" class="displacy" width="2570" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">found</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">inhaling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">mist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">salt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">content</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">7</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">9%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">improved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">lung</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">function</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">and,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">cases,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">produced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">less</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">absenteeism</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">school</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">work.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffafd3181c34077bf6e22144575be80-0-0" stroke-width="2px" d="M70,272.0 C70,227.0 115.0,227.0 115.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffafd3181c34077bf6e22144575be80-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,274.0 L62,262.0 78,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffafd3181c34077bf6e22144575be80-0-1" stroke-width="2px" d="M160,272.0 C160,227.0 205.0,
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="145d9cd734bd4a948b35fdc3076b6457-0" class="displacy" width="3740" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Cystic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">fibrosis,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">progressive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">frequently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">fatal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">genetic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">disease</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">affects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">30,000</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">young</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">adults</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">alone,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">marked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">thickening</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">mucus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">makes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="275
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fea393018a70416ea96aa53dfe5916ec-0" class="displacy" width="3650" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">salt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">water</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">solution &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">really</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">opens</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">avenue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">approaching</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">patients</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">cystic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">fibrosis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">treat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">them,&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">says</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">Dr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Gail</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Weinmann,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">National</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">Heart,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Lung,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curren
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1f2479c3a3b34ed8af95dd6e5e83f7fa-0" class="displacy" width="1850" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Elkins</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Royal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Prince</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">Alfred</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Hospital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">Sydney,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Australia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">colleagues</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">authored</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">studies.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-0" stroke-width="2px" d="M70,272.0 C70,227.0 115.0,227.0 115.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,274.0 L62,262.0 78,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-1" stroke-width="2px" d="M160,272.0 C160,2.0 1220.0,2.0 1220.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,274.0 L152,262.0 168,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-2" stroke-width="2px" d="M160,272.0 C160,227.0 205.0,227.0 205.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M205.0,274.0 L213.0,262.0 197.0,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-3" stroke-width="2px" d="M340,272.0 C340,92.0 670.0,92.0 670.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340,274.0 L332,262.0 348,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1f2479c3a3b34ed8af95dd6e5e83f7fa-0-4" stroke-width="2px" d="M430,272.0 C430,137.0 665.0,137.0 665.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# ...
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="785d5eabf4594a3b8bb730d0c074109f-0" class="displacy" width="2300" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Scientists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">discovered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">infections</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">invade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">whole</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">body,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">malaria,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">disable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">immune</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">system</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">prevent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">detecting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">fighting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">microorganisms.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785d5eabf4594a3b8bb730d0c074109f-0-0" stroke-width="2px" d="M70,272.0 C70,182.0 210.0,182.0 210.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785d5eabf4594a3b8bb730d0c074109f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,274.0 L62,262.0 78,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785d5eabf4594a3b8bb730d0c074109f-0-1" stroke-width="2px" d="M160,272.0 C160,227.0 205.0,227.0 205.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785d5eabf4594a3b8bb730d0c074109f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,274.0 L152,262.0 168,262.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785d5eabf4594a3b8bb730d0c074109f-0-2" stroke-width="2px" d="M340,272.0 C340,47.0 1125.0,47.0 1125.0,272.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="945830927699441a9126e494c8fd3940-0" class="displacy" width="2120" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Australian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">German</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">researchers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">say</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">discovery</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">help</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">scientists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">develop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">vaccines</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">restore</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">immunity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">systemic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">or '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">whol</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-945830927699441a9126e494c8fd3940-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 410.0,2.0 410.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-945830927699441a9126e494c8fd3940-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-945830927699441a9126e494c8fd3940-0-1" stroke-width="2px" d="M160,182.0 C160,47.0 405.0,47.0 405.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-945830927699441a9126e494c8fd3940-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,184.0 L152,172.0 168,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-945830927699441a9126e494c8fd3940-0-2" stroke-width="2px" d="M160,182.0 C160,137.0 215.0,137.0 215.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-945830927699441a9126e494c8fd3940-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,184.0 L223.0,172.0 207.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-945830927699441a9126e494c8fd3940-0-3" stroke-width="2px" d="M160,182.0 C160,92.0 310.0,92.0 310.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy

# %% [markdown]
# ### 3. Use Dependency Parsing, POS tagging to extract relationships between the entities.
# ### 4. Create a tuple for Information Extraction <br>
#  T1( Entity1, Entity2, Relation label, pos1, pos2)<br>
#  T1( Entity1, Entity2, Relation label)
# ### 5. Display no. of such tuples extracted from considered corpus as extracted information

# %%
# Using first 100000 words 
text = nltk.corpus.abc.raw('science.txt')[:100000]

doc = nlp(text)

tuples = []

# Loop through the sentences in the document
for sent in doc.sents:
    # Extract named entities from the sentence
    entities = [(ent.text, ent.label_) for ent in sent.ents]
    # Perform dependency parsing and POS tagging on the sentence
    for token in sent:
        if token.text in [ent[0] for ent in entities]:
            for child in token.children:
                if child.text in [ent[0] for ent in entities]:
                    # Extract the relation label and POS tags
                    label = token.dep_
                    pos1 = token.pos_
                    pos2 = child.pos_
                    # Get the entity texts and labels
                    entity1 = [(ent[0], ent[1]) for ent in entities if ent[0] == token.text][0]
                    entity2 = [(ent[0], ent[1]) for ent in entities if ent[0] == child.text][0]
                    # Create a tuple and add it to the list
                    tuple = (entity1, entity2, label, pos1, pos2)
                    tuples.append(tuple)

print("Number of tuples extracted:", len(tuples))
print()

for tuple in tuples:
    print(tuple)
# Out:
# Number of tuples extracted: 34
#
# (('Sydney', 'GPE'), ('Australia', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Toronto', 'GPE'), ('Canada', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Australian', 'NORP'), ('German', 'NORP'), 'amod', 'ADJ', 'ADJ')
# (('Jews', 'NORP'), ('Ashkenazi', 'NORP'), 'pobj', 'PROPN', 'PROPN')
# (('Europe', 'LOC'), ('US', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Jews', 'NORP'), ('European', 'NORP'), 'pobj', 'PROPN', 'ADJ')
# (('Jews', 'NORP'), ('Ashkenazi', 'NORP'), 'attr', 'PROPN', 'PROPN')
# (('CSIRO', 'ORG'), ('NASA', 'ORG'), 'conj', 'PROPN', 'PROPN')
# (('Australia', 'GPE'), ('US', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('US', 'GPE'), ('Europe', 'LOC'), 'appos', 'PROPN', 'PROPN')
# (('Europe', 'LOC'), ('Canada', 'GPE'), 'conj', 'PROPN', 'PROPN')
# (('Canada', 'GPE'), ('Japan', 'GPE'), 'conj', 'PROPN', 'PROPN')
# (('Boulder', 'GPE'), ('Colorado', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Valley', 'LOC'), ('Egypt', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Antartica', 'GPE'), ('Canada', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('seven', 'CARDINAL'), ('eight', 'CARDINAL'), 'nummod', 'NUM', 'NUM')
# (('Ketek', 'PERSON'), ('Aventis', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('US', 'GPE'), ('French', 'NORP'), 'nmod', 'PROPN', 'ADJ')
# (('10,000', 'MONEY'), ('7500', 'MONEY'), 'pobj', 'NUM', 'NUM')
# (('year', 'DATE'), ('two', 'CARDINAL'), 'npadvmod', 'NOUN', 'NUM')
# (('MatScape', 'ORG'), ('Joachim', 'PERSON'), 'nsubj', 'PROPN', 'PROPN')
# (('Ethiopia', 'GPE'), ('Egypt', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Egypt', 'GPE'), ('Libya', 'GPE'), 'conj', 'PROPN', 'PROPN')
# (('BC', 'ORG'), ('430', 'CARDINAL'), 'pobj', 'PROPN', 'NUM')
# (('BC', 'ORG'), ('426', 'CARDINAL'), 'pobj', 'PROPN', 'NUM')
# (('Athens', 'GPE'), ('Sparta', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Typhi', 'NORP'), ('Salmonella', 'ORG'), 'dobj', 'PROPN', 'PROPN')
# (('Victoria', 'GPE'), ('Australia', 'GPE'), 'conj', 'PROPN', 'PROPN')
# (('Europeans', 'NORP'), ('first', 'ORDINAL'), 'attr', 'PROPN', 'ADJ')
# (('Earth', 'LOC'), ('Sun', 'ORG'), 'pobj', 'PROPN', 'PROPN')
# (('Moon', 'PERSON'), ('Mars', 'LOC'), 'pobj', 'PROPN', 'PROPN')
# (('okeeffeae', 'GPE'), ('Effigia', 'FAC'), 'oprd', 'ADJ', 'PROPN')
# (('Triassic', 'GPE'), ('Jurassic', 'GPE'), 'pobj', 'PROPN', 'PROPN')
# (('Steffen', 'PERSON'), ('Nettleton', 'GPE'), 'nsubj', 'PROPN', 'PROPN')

# %%
# Display the extracted tuples
for tuple in tuples:
    print(tuple[:3])
# Out:
# (('Sydney', 'GPE'), ('Australia', 'GPE'), 'pobj')
# (('Toronto', 'GPE'), ('Canada', 'GPE'), 'pobj')
# (('Australian', 'NORP'), ('German', 'NORP'), 'amod')
# (('Jews', 'NORP'), ('Ashkenazi', 'NORP'), 'pobj')
# (('Europe', 'LOC'), ('US', 'GPE'), 'pobj')
# (('Jews', 'NORP'), ('European', 'NORP'), 'pobj')
# (('Jews', 'NORP'), ('Ashkenazi', 'NORP'), 'attr')
# (('CSIRO', 'ORG'), ('NASA', 'ORG'), 'conj')
# (('Australia', 'GPE'), ('US', 'GPE'), 'pobj')
# (('US', 'GPE'), ('Europe', 'LOC'), 'appos')
# (('Europe', 'LOC'), ('Canada', 'GPE'), 'conj')
# (('Canada', 'GPE'), ('Japan', 'GPE'), 'conj')
# (('Boulder', 'GPE'), ('Colorado', 'GPE'), 'pobj')
# (('Valley', 'LOC'), ('Egypt', 'GPE'), 'pobj')
# (('Antartica', 'GPE'), ('Canada', 'GPE'), 'pobj')
# (('seven', 'CARDINAL'), ('eight', 'CARDINAL'), 'nummod')
# (('Ketek', 'PERSON'), ('Aventis', 'GPE'), 'pobj')
# (('US', 'GPE'), ('French', 'NORP'), 'nmod')
# (('10,000', 'MONEY'), ('7500', 'MONEY'), 'pobj')
# (('year', 'DATE'), ('two', 'CARDINAL'), 'npadvmod')
# (('MatScape', 'ORG'), ('Joachim', 'PERSON'), 'nsubj')
# (('Ethiopia', 'GPE'), ('Egypt', 'GPE'), 'pobj')
# (('Egypt', 'GPE'), ('Libya', 'GPE'), 'conj')
# (('BC', 'ORG'), ('430', 'CARDINAL'), 'pobj')
# (('BC', 'ORG'), ('426', 'CARDINAL'), 'pobj')
# (('Athens', 'GPE'), ('Sparta', 'GPE'), 'pobj')
# (('Typhi', 'NORP'), ('Salmonella', 'ORG'), 'dobj')
# (('Victoria', 'GPE'), ('Australia', 'GPE'), 'conj')
# (('Europeans', 'NORP'), ('first', 'ORDINAL'), 'attr')
# (('Earth', 'LOC'), ('Sun', 'ORG'), 'pobj')
# (('Moon', 'PERSON'), ('Mars', 'LOC'), 'pobj')
# (('okeeffeae', 'GPE'), ('Effigia', 'FAC'), 'oprd')
# (('Triassic', 'GPE'), ('Jurassic', 'GPE'), 'pobj')
# (('Steffen', 'PERSON'), ('Nettleton', 'GPE'), 'nsubj')
